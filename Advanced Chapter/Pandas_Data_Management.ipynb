# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
df = pd.read_csv("hf://datasets/lukebarousse/data_jobs/data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#                   job_title_short  \
# 157334              Data Engineer
# 731546             Data Scientist
# 566217      Senior Data Scientist
# 225068               Data Analyst
# 124750      Senior Data Scientist
# 684688             Data Scientist
# 156795       Senior Data Engineer
# 776279               Data Analyst
# 751086               Data Analyst
# 632365  Machine Learning Engineer
#
#                                                 job_title  \
# 157334                                Telco Data Engineer
# 731546  Data Scientist Digital Search Ads Marketer exp...
# 566217                                     Senior Analyst
# 225068                                       Data Analyst
# 124750                                Senior Data Modeler
# 684688                              Digital Media Analyst
# 156795                               Senior Data Engineer
# 776279           Flight Operations Training Data Analysts
# ...

# %%
#Creating a copy of a dataframe. PS!! - создал слишком много переменных, это необязательно - просто с предыдущим объединил бездумно, но смысл тот же сработал - при создании копии изначальная версия остается сохранной

df_original = df

# %%
#But this assignment will be permanent. How to leave the initial dataframe intact?
df_original = df.copy()

# %%
medium_salary_year = df_original['salary_year_avg'].median()
medium_salary_year
# Out:
# 115000.0

# %%
df_filled = df_original
df_filled['salary_year_avg'] = df_original['salary_year_avg'].fillna(medium_salary_year)

# %%
df_filled.loc[0:10,'salary_year_avg']
# Out:
# 0     115000.0
# 1     115000.0
# 2     115000.0
# 3     115000.0
# 4     115000.0
# 5     115000.0
# 6     115000.0
# 7     115000.0
# 8     115000.0
# 9     115000.0
# 10    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df.loc[0:10,'salary_year_avg']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# Name: salary_year_avg, dtype: float64
